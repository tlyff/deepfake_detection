# %% [markdown]
#  **se connecter à son drive**

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount = True)

# %% [markdown]
# **display function**

# %%
import imageio
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from skimage.transform import resize
from IPython.display import HTML
import warnings
warnings.filterwarnings("ignore")
from random import *
import os


def display(source, driving, generated=None):
    fig = plt.figure(figsize=(8 + 4 * (generated is not None), 6))

    ims = []
    for i in range(len(driving)):
        cols = [source]
        cols.append(driving[i])
        if generated is not None:
            cols.append(generated[i])
        im = plt.imshow(np.concatenate(cols, axis=1), animated=True)
        plt.axis('off')
        ims.append([im])

    ani = animation.ArtistAnimation(fig, ims, interval=50, repeat_delay=1000)
    plt.close()
    return ani

# %% [markdown]
# **code to run**

# %%
import imageio
from PIL import Image
import random
import os

compteur = 1536

for element in os.listdir('/content/gdrive/My Drive/voxtest'):
  driving_video = imageio.mimread('/content/gdrive/My Drive/voxtest/'+ element)
  driving_video = [resize(frame, (256, 256))[..., :3] for frame in driving_video]
  Lbis= [frame for frame in driving_video]
  a = random.randint(0, len(Lbis)-1)
  img = Lbis[a]
  img = resize(img, (256, 256))[..., :3]

    #Save it in voxtest-frames folder                      
  imageio.imwrite('/content/gdrive/My Drive/voxtest-frames/' + str(compteur) + '.png', img)

  compteur += 1

# %% [markdown]
# **test code**

# %%
import imageio
from PIL import Image
from random import *

driving_video = imageio.mimread('/content/gdrive/My Drive/output/0.mp4')
driving_video = [resize(frame, (256, 256))[..., :3] for frame in driving_video]
L= [frame for frame in driving_video]
a = randint(0, len(Lbis)-1)
print(a)
img = Lbis[a]
img = resize(img, (256, 256))[..., :3]



    #Save it in output folder                      
imageio.imwrite('/content/gdrive/My Drive/output-frames/test.png', img)

HTML(display(img, driving_video).to_html5_video())
# Out:
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# 90
# <video width="576" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...
